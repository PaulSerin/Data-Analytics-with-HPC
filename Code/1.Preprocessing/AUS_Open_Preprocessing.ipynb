# %% [markdown]
# ## AUSTRALIAN OPEN 2025 PREDICTION

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, f1_score, log_loss, classification_report, confusion_matrix
import sys
from pathlib import Path

utils_path = Path("../0.Utils").resolve()
sys.path.append(str(utils_path))
from utils import COLS_TO_EXCLUDE

# %%
df_kaggle = pd.read_csv("../../Data/2025/atp_tennis_2025.csv")

df_kaggle["Date"] = pd.to_datetime(df_kaggle["Date"], errors='coerce')
df_2025 = df_kaggle[df_kaggle["Date"].dt.year == 2025].copy()

df_aus_open_2025 = df_2025[df_2025["Tournament"] == "Australian Open"]

print(f"{len(df_aus_open_2025)} matches found for AUS OPEN 2025")
df_aus_open_2025.head()
# Out:
# 116 matches found for AUS OPEN 2025
#             Tournament       Date      Series    Court Surface      Round  \
# 64271  Australian Open 2025-01-12  Grand Slam  Outdoor    Hard  1st Round
# 64272  Australian Open 2025-01-12  Grand Slam  Outdoor    Hard  1st Round
# 64273  Australian Open 2025-01-12  Grand Slam  Outdoor    Hard  1st Round
# 64274  Australian Open 2025-01-12  Grand Slam  Outdoor    Hard  1st Round
# 64275  Australian Open 2025-01-12  Grand Slam  Outdoor    Hard  1st Round
#
#        Best of     Player_1      Player_2        Winner  Rank_1  Rank_2  \
# 64271        5    Jasika O.     Gaston H.     Gaston H.     179      81
# 64272        5      Fils A.   Virtanen O.       Fils A.      21      93
# 64273        5  Monteiro T.  Nishikori K.  Nishikori K.     105      76
# 64274        5      Ruud C.      Munar J.       Ruud C.       6      62
# 64275        5        Bu Y.      Habib H.      Habib H.      67     219
#
#        Pts_1  Pts_2  Odd_1  Odd_2                Score
# 64271    323    703   3.20   1.36      2-6 6-3 2-6 2-6
# 64272   2280    627   1.13   6.00      3-6 7-6 6-4 6-4
# 64273    566    743   4.50   1.20  6-4 7-6 5-7 2-6 3-6
# 64274   4210    922   1.17   5.00  6-3 1-6 7-5 2-6 6-1
# 64275    784    264   1.36   3.20          6-7 4-6 6-7

# %%
csv_path = Path('../../Datasets/aus_open_2025.csv')
df_aus_open_2025.to_csv(csv_path, index=False)

# %% [markdown]
# ---

# %%
import pandas as pd
from pathlib import Path

def name_label_to_id_verbose(label: str, csv_path: Path) -> int:
    """
    Tente de convertir un label "Last F." (ex. "Monfils G.") en ATP ID.
    Affiche un warning uniquement si aucune correspondance ou plusieurs correspondances.
    """
    parts = label.strip().split()
    if len(parts) < 2:
        raise ValueError(f"Label inattendu : {label!r}")
    last_name      = parts[0]
    first_initial  = parts[1].replace('.', '')[0].lower()

    # Lecture du CSV ATP (sans header)
    players = pd.read_csv(
        csv_path,
        names=["id","first","last","hand","dob","ioc","height","wikidata"],
        header=None
    )

    # 1) Filtre sur le nom de famille
    mask_last       = players["last"].str.lower().str.strip() == last_name.lower().strip()
    candidates_last = players[mask_last]

    if len(candidates_last) == 0:
        print(f"⚠️ Aucun joueur trouvé avec le nom '{last_name}' pour label {label!r}")
    elif len(candidates_last) > 1:
        print(f"⚠️ Plusieurs joueurs trouvés avec le nom '{last_name}' :")
        print(candidates_last[["id","first","last"]])

    # 2) Filtre sur l'initiale du prénom
    candidates = candidates_last[candidates_last["first"].str.lower().str.startswith(first_initial)]
    if len(candidates) == 0:
        print(f"⚠️ Aucun joueur restant après filtre initiale '{first_initial.upper()}' pour {label!r}")
    elif len(candidates) > 1:
        print(f"⚠️ Plusieurs joueurs restants après filtre initiale '{first_initial.upper()}' :")
        print(candidates[["id","first","last"]])

    if len(candidates) != 1:
        raise ValueError(f"Impossible de résoudre de façon unique l'ID pour {label!r}")

    return int(candidates.iloc[0]["id"])

# Exemple de test
atp_csv = Path('../../Data/players/atp_players.csv')
test_labels = ["Monfils G.", "Smith J.", "Djokovic N."]

for lbl in test_labels:
    try:
        pid = name_label_to_id_verbose(lbl, atp_csv)
        print(f"✔️ {lbl} → ID {pid}")
    except Exception as e:
        print(f"❌ Erreur pour {lbl}: {e}")
# Out:
# ⚠️ Plusieurs joueurs trouvés avec le nom 'Monfils' :
#            id  first     last
# 4789   104792   Gael  Monfils
# 27885  127900  Daryl  Monfils
# ✔️ Monfils G. → ID 104792
# ⚠️ Plusieurs joueurs trouvés avec le nom 'Smith' :
#            id     first   last
# 126    100126      Stan  Smith
# 364    100364  Jonathan  Smith
# 741    100741   Darrell  Smith
# 867    100867      Mike  Smith
# 997    100997     Roger  Smith
# ...       ...       ...    ...
# 64210  211925       J I  Smith
# 64541  212256    Colton  Smith
# 64702  212417         I  Smith
# 64709  212424         G  Smith
# 65557  213272   Maxwell  Smith
#
# [170 rows x 3 columns]
# ⚠️ Plusieurs joueurs restants après filtre initiale 'J' :
#            id         first   last
# 364    100364      Jonathan  Smith
# 2688   102688         Jason  Smith
# 5430   105441  John Patrick  Smith
# 8844   108858      Jermaine  Smith
# 10390  110404         James  Smith
# 12023  112038           J K  Smith
# 39513  139528        Joshua  Smith
# 39638  139653          Jack  Smith
# 44194  144209        Joseph  Smith
# 46037  146053             J  Smith
# 47985  148001          John  Smith
# 51430  151446           J O  Smith
# 54334  202047        Jordon  Smith
# 57257  204970        Jordan  Smith
# 61720  209433        Jeremy  Smith
# 64210  211925           J I  Smith
# ❌ Erreur pour Smith J.: Impossible de résoudre de façon unique l'ID pour 'Smith J.'
# ⚠️ Plusieurs joueurs trouvés avec le nom 'Djokovic' :
#            id    first      last
# 4920   104925    Novak  Djokovic
# 5817   105831    Marko  Djokovic
# 10449  110463  Djordje  Djokovic
# ✔️ Djokovic N. → ID 104925
# /tmp/ipykernel_18431/2802938589.py:16: DtypeWarning: Columns (0,4,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   players = pd.read_csv(
# /tmp/ipykernel_18431/2802938589.py:16: DtypeWarning: Columns (0,4,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   players = pd.read_csv(
# /tmp/ipykernel_18431/2802938589.py:16: DtypeWarning: Columns (0,4,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   players = pd.read_csv(

# %%
import pandas as pd
import json
from pathlib import Path

def name_label_to_id(label: str, csv_path: Path) -> int | None:
    """
    Convert a label "Last F." (e.g., "Monfils G.") to an ATP player ID.
    If no candidate or multiple candidates are found, return None and print warnings.
    """
    parts = label.strip().split()
    if len(parts) < 2:
        raise ValueError(f"Invalid label format: {label!r}")
    last_name = parts[0]
    first_initial = parts[1].replace('.', '')[0].lower()

    # Read ATP players CSV with low_memory=False to suppress dtype warnings
    players = pd.read_csv(
        csv_path,
        names=["id", "first", "last", "hand", "dob", "ioc", "height", "wikidata"],
        header=None,
        low_memory=False
    )

    # 1) Filter by last name
    mask_last = players["last"].str.lower().str.strip() == last_name.lower().strip()
    candidates_last = players[mask_last]
    if candidates_last.empty:
        print(f"WARNING: No players found with last name '{last_name}' for label '{label}'.")
        return None

    # 2) Filter by first name initial (na=False handles missing values)
    mask_first = candidates_last["first"].str.lower().str.startswith(first_initial, na=False)
    candidates = candidates_last[mask_first]
    if candidates.empty:
        print(f"WARNING: No players with initial '{first_initial.upper()}' for label '{label}'.")
        return None

    # 3) Handle multiple matches
    if len(candidates) > 1:
        print(f"WARNING: Multiple candidates for label '{label}':")
        print(candidates[["id", "first", "last"]].to_string(index=False))
        return None

    # 4) Exactly one match
    return int(candidates.iloc[0]["id"])

# Paths (ensure these are correct on your filesystem)
aus_csv = Path('../../Datasets/aus_open_2025.csv')
atp_csv = Path('../../Data/players/atp_players.csv')
output_json = Path('../../Datasets/aus_open_2025_matches.json')

# Load and filter Australian Open data
df = pd.read_csv(aus_csv)
df = df[df['Tournament'] == 'Australian Open']

# Prepare JSON structure
tournament = {
    "tournament": "Australian Open 2025",
    "surface":    df['Surface'].iloc[0].upper(),
    "start_date": df['Date'].min(),
    "matches":    []
}

# Build each match entry
match_id = 1
for _, row in df.iterrows():
    p1_label, p2_label = row['Player_1'], row['Player_2']
    id1 = name_label_to_id(p1_label, atp_csv)
    id2 = name_label_to_id(p2_label, atp_csv)

    # Determine outcome
    winner = row.get('Winner')
    outcome = None
    if winner == p1_label:
        outcome = "player1"
    elif winner == p2_label:
        outcome = "player2"

    tournament["matches"].append({
        "round":    row['Round'],
        "match_id": match_id,
        "player1":  {"name": p1_label, "id": id1},
        "player2":  {"name": p2_label, "id": id2},
        "outcome":  outcome
    })
    match_id += 1

# Write JSON to disk
with open(output_json, 'w', encoding='utf-8') as f:
    json.dump(tournament, f, ensure_ascii=False, indent=2)

print(f"JSON file generated at: {output_json}")
# Out:
# WARNING: Multiple candidates for label 'Ruud C.':
#     id     first last
# 102104 Christian Ruud
# 134770    Casper Ruud
# WARNING: No players found with last name 'Bu' for label 'Bu Y.'.
# WARNING: Multiple candidates for label 'Gigante M.':
#     id  first    last
# 209261 Matteo Gigante
# 209263 Matteo Gigante
# WARNING: No players found with last name 'Carballes' for label 'Carballes Baena R.'.
# WARNING: Multiple candidates for label 'Mensik J.':
#     id first   last
# 210084 Jakub Mensik
# 210150 Jakub Mensik
# WARNING: Multiple candidates for label 'Muller A.':
#     id     first   last
# 124186 Alexandre Muller
# 142378    Arthur Muller
# WARNING: No players found with last name 'Seyboth' for label 'Seyboth Wild T.'.
# WARNING: Multiple candidates for label 'Landaluce M.':
#     id  first      last
# 211776 Martin Landaluce
# 212021 Martin Landaluce
# WARNING: Multiple candidates for label 'Mccabe J.':
#     id first   last
# 147511   Jim Mccabe
# 210317 James Mccabe
# 212324  John Mccabe
# WARNING: Multiple candidates for label 'Thompson J.':
#     id    first     last
# 107270    James Thompson
# 111388    Jason Thompson
# 111442   Jordan Thompson
# 111683    Jamin Thompson
# 128290 Jonathan Thompson
# 132208     John Thompson
# 147490    Jerry Thompson
# WARNING: Multiple candidates for label 'Draper J.':
#     id      first   last
# 117272 Jose Maria Draper
# 145281        J K Draper
# 207733       Jack Draper
# WARNING: Multiple candidates for label 'Nishioka Y.':
#     id     first     last
# 106415 Yoshihito Nishioka
# 132399     Yasuo Nishioka
# WARNING: Multiple candidates for label 'Klein L.':
#     id    first  last
# 127760    Lukas Klein
# 140284  Laurent Klein
# 147680 Ladislav Klein
# WARNING: No players found with last name 'Auger-Aliassime' for label 'Auger-Aliassime F.'.
# WARNING: Multiple candidates for label 'Paul T.':
#     id first last
# 104652  Todd Paul
# 126205 Tommy Paul
# WARNING: No players found with last name 'O' for label 'O Connell C.'.
# WARNING: Multiple candidates for label 'Zhang Zh.':
#     id             first  last
# 105585                Ze Zhang
# 111190           Zhizhen Zhang
# 118842               Zhe Zhang
# 122195              Ziyu Zhang
# 123735              Zhuo Zhang
# 138374       Zhong Zheng Zhang
# 207405 Zheng Qi Jonathan Zhang
# WARNING: No players found with last name 'Ugo' for label 'Ugo Carabelli C.'.
# WARNING: No players found with last name 'Mpetshi' for label 'Mpetshi G.'.
# WARNING: Multiple candidates for label 'Diaz Acosta F.':
#     id         first last
# 106497     Alexandre Diaz
# 120236     Alexander Diaz
# 131821        Alexis Diaz
# 136315 Alvaro Felipe Diaz
# 200274          Alex Diaz
# WARNING: Multiple candidates for label 'Nakashima B.':
#     id   first      last
# 206909 Brandon Nakashima
# 210416   Bryce Nakashima
# WARNING: Multiple candidates for label 'Shelton B.':
#     id first    last
# 101214 Bryan Shelton
# 210097   Ben Shelton
# WARNING: Multiple candidates for label 'Boyer T.':
#     id   first  last
# 207729 Tristan Boyer
# 208142  Toby D Boyer
# WARNING: Multiple candidates for label 'Krueger M.':
#     id    first    last
# 106283 Mitchell Krueger
# 205546   Martin Krueger
# WARNING: Multiple candidates for label 'Popyrin A.':
#     id   first    last
# 200615  Alexei Popyrin
# 202270 Anthony Popyrin
# WARNING: No players with initial 'D' for label 'Van De Zandschulp B.'.
# WARNING: No players with initial 'M' for label 'De Minaur A.'.
# WARNING: No players found with last name 'Carreno' for label 'Carreno Busta P.'.
# WARNING: Multiple candidates for label 'Fonseca J.':
#     id  first    last
# 128159 Joshua Fonseca
# 211663   Joao Fonseca
# WARNING: Multiple candidates for label 'Nishioka Y.':
#     id     first     last
# 106415 Yoshihito Nishioka
# 132399     Yasuo Nishioka
# WARNING: Multiple candidates for label 'Thompson J.':
#     id    first     last
# 107270    James Thompson
# 111388    Jason Thompson
# 111442   Jordan Thompson
# 111683    Jamin Thompson
# 128290 Jonathan Thompson
# 132208     John Thompson
# 147490    Jerry Thompson
# WARNING: No players found with last name 'Carballes' for label 'Carballes Baena R.'.
# WARNING: Multiple candidates for label 'Ruud C.':
#     id     first last
# 102104 Christian Ruud
# 134770    Casper Ruud
# WARNING: Multiple candidates for label 'Mensik J.':
#     id first   last
# 210084 Jakub Mensik
# 210150 Jakub Mensik
# WARNING: Multiple candidates for label 'Draper J.':
#     id      first   last
# 117272 Jose Maria Draper
# 145281        J K Draper
# 207733       Jack Draper
# WARNING: No players found with last name 'Auger-Aliassime' for label 'Auger-Aliassime F.'.
# WARNING: No players found with last name 'Davidovich' for label 'Davidovich Fokina A.'.
# WARNING: Multiple candidates for label 'Martinez P.':
#     id first     last
# 103492 Pablo Martinez
# 124079 Pedro Martinez
# WARNING: Multiple candidates for label 'Paul T.':
#     id first last
# 104652  Todd Paul
# 126205 Tommy Paul
# WARNING: No players found with last name 'Carreno' for label 'Carreno Busta P.'.
# WARNING: Multiple candidates for label 'Shelton B.':
#     id first    last
# 101214 Bryan Shelton
# 210097   Ben Shelton
# WARNING: No players with initial 'M' for label 'De Minaur A.'.
# WARNING: Multiple candidates for label 'Boyer T.':
#     id   first  last
# 207729 Tristan Boyer
# 208142  Toby D Boyer
# WARNING: Multiple candidates for label 'Krueger M.':
#     id    first    last
# 106283 Mitchell Krueger
# 205546   Martin Krueger
# WARNING: Multiple candidates for label 'Fritz T.':
#     id  first  last
# 126203 Taylor Fritz
# 205176 Thomas Fritz
# WARNING: Multiple candidates for label 'Mccabe J.':
#     id first   last
# 147511   Jim Mccabe
# 210317 James Mccabe
# 212324  John Mccabe
# WARNING: Multiple candidates for label 'Fonseca J.':
#     id  first    last
# 128159 Joshua Fonseca
# 211663   Joao Fonseca
# WARNING: Multiple candidates for label 'Paul T.':
#     id first last
# 104652  Todd Paul
# 126205 Tommy Paul
# WARNING: No players found with last name 'Carballes' for label 'Carballes Baena R.'.
# WARNING: Multiple candidates for label 'Mensik J.':
#     id first   last
# 210084 Jakub Mensik
# 210150 Jakub Mensik
# WARNING: No players found with last name 'Davidovich' for label 'Davidovich Fokina A.'.
# WARNING: Multiple candidates for label 'Draper J.':
#     id      first   last
# 117272 Jose Maria Draper
# 145281        J K Draper
# 207733       Jack Draper
# WARNING: Multiple candidates for label 'Fritz T.':
#     id  first  last
# 126203 Taylor Fritz
# 205176 Thomas Fritz
# WARNING: No players with initial 'M' for label 'De Minaur A.'.
# WARNING: Multiple candidates for label 'Shelton B.':
#     id first    last
# 101214 Bryan Shelton
# 210097   Ben Shelton
# WARNING: No players found with last name 'Davidovich' for label 'Davidovich Fokina A.'.
# WARNING: Multiple candidates for label 'Paul T.':
#     id first last
# 104652  Todd Paul
# 126205 Tommy Paul
# WARNING: No players with initial 'M' for label 'De Minaur A.'.
# WARNING: Multiple candidates for label 'Paul T.':
#     id first last
# 104652  Todd Paul
# 126205 Tommy Paul
# WARNING: Multiple candidates for label 'Shelton B.':
#     id first    last
# 101214 Bryan Shelton
# 210097   Ben Shelton
# WARNING: No players with initial 'M' for label 'De Minaur A.'.
# WARNING: Multiple candidates for label 'Shelton B.':
#     id first    last
# 101214 Bryan Shelton
# 210097   Ben Shelton
# JSON file generated at: ../../Datasets/aus_open_2025_matches.json

# %% [markdown]
# ---

# %%
import json
from pathlib import Path

# Path to the JSON file
json_path = Path('../../Datasets/aus_open_2025_matches_all_ids.json')
# Load the JSON data
with open(json_path, 'r', encoding='utf-8') as f:
    tournament = json.load(f)

# Find and list all null IDs
null_entries = []
for match in tournament.get("matches", []):
    mid = match.get("match_id")
    p1 = match["player1"]
    p2 = match["player2"]
    if p1.get("id") is None:
        null_entries.append((mid, "player1", p1.get("name")))
    if p2.get("id") is None:
        null_entries.append((mid, "player2", p2.get("name")))

# Count and display
total_nulls = len(null_entries)
print(f"Total null IDs: {total_nulls}")
print("List of null ID entries (match_id, player_role, player_name):")
for match_id, role, name in null_entries:
    print(f"  Match {match_id}: {role} → {name}")
# Out:
# Total null IDs: 0
# List of null ID entries (match_id, player_role, player_name):
